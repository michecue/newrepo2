# %% [markdown]
# <a href="https://colab.research.google.com/github/michecue/newrepo2/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1
print("hello world")
# Out:
# hello world

# %%
#fa3prog2
print("Hello pisay")
# Out:
# Hello pisay

# %%
#fa3prog3
print("Greetings")
# Out:
# Greetings
